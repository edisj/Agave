# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-1-8fd2e8d3bc12>:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
columns = ['rank', 'init total', 'init topology', 'init trajectory', 
           'loop', 'loop/frame', 'io', 'io/frame', 'rmsd compute', 
           'rmsd compute/frame', 'comm init', 'comm gather',
           'comm total', 'total bench']

# %%
def load_arrays(N, n, cols):
    a_1 = np.load(f'{N}node_1/{n}process_times.npy')
    a_2 = np.load(f'{N}node_2/{n}process_times.npy')
    a_3 = np.load(f'{N}node_3/{n}process_times.npy')
    
    a = np.hstack((a_1, a_2, a_3))
    
    dframe = pd.DataFrame(list(a), columns=3*cols)

    return dframe

# %% [markdown]
# # Load arrays for each job with $N_{nodes}$ containing runs for $n_{processes}$ and stack the repeats horizontally, then display as pandas dataframe

# %% [markdown]
# # 1 NODE

# %% [markdown]
# ### 1 core:

# %%
load_arrays(N=1, n=1, cols=columns)
# Out:
#    rank  init total  init topology  init trajectory         loop  loop/frame  \
# 0  0.0   5.713634    5.421492       0.287149         3243.135501  0.035995
#
#             io  io/frame  rmsd compute  rmsd compute/frame  comm init  \
# 0  3230.015695  0.035849  12.6891       0.000141            0.000005
#
#    comm gather  comm total  total bench  rank  init total  init topology  \
# 0  0.000363     0.00037     3248.849505  0.0   4.80499     3.702396
#
#    init trajectory        loop  loop/frame           io  io/frame  \
# 0  1.097256         3087.89586  0.034272    3074.345706  0.034121
#
#    rmsd compute  rmsd compute/frame  comm init  comm gather  comm total  \
# 0  13.07697      0.000145            0.000005   0.000247     0.000255
#
#    total bench  rank  init total  init topology  init trajectory         loop  \
# 0  3092.701105  0.0   3.305004    2.922888       0.376691         3876.353538
#
#    loop/frame           io  io/frame  rmsd compute  rmsd compute/frame  \
# ...

# %% [markdown]
# ### 2 cores:

# %%
load_arrays(N=1, n=2, cols=columns)
# Out:
#    rank  init total  init topology  init trajectory         loop  loop/frame  \
# 0  0.0   3.713493    3.420310       0.287734         1740.506051  0.038635
# 1  1.0   3.713150    3.425367       0.282561         1706.398718  0.037878
#
#             io  io/frame  rmsd compute  rmsd compute/frame     comm init  \
# 0  1731.523818  0.038436  8.659038      0.000192            5.245209e-06
# 1  1698.065630  0.037693  8.030402      0.000178            7.152557e-07
#
#    comm gather  comm total  total bench  rank  init total  init topology  \
# 0  0.000379     0.000387    1744.219930  0.0   7.379321    6.970694
# 1  34.108188    34.108192   1744.220059  1.0   7.379579    7.076058
#
#    init trajectory         loop  loop/frame           io  io/frame  \
# 0  0.403284         1635.586204  0.036306    1628.034511  0.036138
# 1  0.298805         1758.805490  0.039041    1750.189494  0.038850
#
#    rmsd compute  rmsd compute/frame     comm init  comm gather  comm total  \
# ...

# %% [markdown]
# ### 4 cores:

# %%
load_arrays(N=1, n=4, cols=columns)
# Out:
#    rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0  0.0   3.330545    2.991189       0.334503         951.356776  0.042236
# 1  1.0   3.331836    2.965725       0.360916         932.049029  0.041378
# 2  2.0   3.331836    3.069725       0.256905         953.219274  0.042318
# 3  3.0   3.332973    2.958163       0.369539         929.017715  0.041244
#
#            io  io/frame  rmsd compute  rmsd compute/frame     comm init  \
# 0  947.145051  0.042049  4.058304      0.000180            8.344650e-06
# 1  928.731988  0.041231  3.206529      0.000142            7.152557e-07
# 2  949.021958  0.042132  4.042639      0.000179            4.768372e-07
# 3  925.670439  0.041095  3.238733      0.000144            4.768372e-07
#
#    comm gather  comm total  total bench  rank  init total  init topology  \
# 0  1.863871     1.863885    956.551206   0.0   3.305704    2.793341
# 1  19.307072    19.307075   954.687939   1.0   3.238306    2.718932
# ...

# %% [markdown]
# ### 8 cores:

# %%
load_arrays(N=1, n=8, cols=columns)
# Out:
#    rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0  0.0   2.963429    2.368098       0.588698         546.193015  0.048494
# 1  1.0   2.964761    2.286798       0.672110         538.213008  0.047786
# 2  2.0   2.964152    2.301167       0.657297         543.966477  0.048297
# 3  3.0   2.964267    2.310716       0.647666         541.683568  0.048094
# 4  4.0   2.961738    2.622849       0.334312         544.450941  0.048344
# 5  5.0   2.963918    2.331897       0.626267         540.957984  0.048034
# 6  6.0   2.963815    2.324432       0.633553         546.185722  0.048498
# 7  7.0   2.964241    2.288098       0.670154         542.374969  0.048160
#
#            io  io/frame  rmsd compute  rmsd compute/frame     comm init  \
# 0  543.943790  0.048295  2.166261      0.000192            1.096725e-05
# 1  536.224519  0.047609  1.914622      0.000170            7.152557e-07
# 2  541.692935  0.048095  2.188871      0.000194            9.536743e-07
# ...

# %% [markdown]
# ### 16 cores:

# %%
load_arrays(N=1, n=16, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   2.484453    2.320109       0.160533         375.922963  0.066748
# 1   1.0   2.479522    2.105533       0.369982         369.042884  0.065526
# 2   2.0   2.480644    2.176130       0.300687         374.819970  0.066552
# 3   3.0   2.486748    2.040645       0.440272         368.455789  0.065422
# 4   4.0   2.484062    2.054682       0.422816         374.417935  0.066492
# 5   5.0   2.480699    2.026164       0.450645         370.495447  0.065796
# 6   6.0   2.483691    2.117622       0.358988         375.981790  0.066770
# 7   7.0   2.487695    1.984838       0.496582         370.076642  0.065721
# 8   8.0   2.483564    2.196307       0.281921         375.646403  0.066710
# 9   9.0   2.483607    2.027330       0.450642         370.312907  0.065763
# 10  10.0  2.487848    2.058002       0.423541         374.630845  0.066530
# ...

# %% [markdown]
# ### 24 cores:

# %%
load_arrays(N=1, n=24, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   4.361346    4.200086       0.157285         374.870403  0.099832
# 1   1.0   4.359488    4.184163       0.171477         366.659151  0.097646
# 2   2.0   4.442667    4.155444       0.283378         373.437528  0.099451
# 3   3.0   4.356406    3.999395       0.353571         366.120609  0.097502
# 4   4.0   4.361234    4.194801       0.162452         373.531640  0.099502
# 5   5.0   4.362529    4.136100       0.222684         366.631787  0.097664
# 6   6.0   4.360943    4.211037       0.145937         374.429643  0.099742
# 7   7.0   4.357541    3.994179       0.359928         366.705394  0.097684
# 8   8.0   4.362575    4.201070       0.157735         374.909611  0.099869
# 9   9.0   4.356266    3.985990       0.366821         367.321368  0.097848
# 10  10.0  4.360418    4.160034       0.196357         373.440192  0.099478
# ...

# %% [markdown]
# ### 28 cores:

# %%
load_arrays(N=1, n=28, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   3.893200    3.607270       0.282344         377.023643  0.117161
# 1   1.0   3.893694    3.484479       0.405689         364.396546  0.113237
# 2   2.0   3.887588    3.583242       0.300877         375.567547  0.116708
# 3   3.0   3.889591    3.479539       0.406428         361.674081  0.112391
# 4   4.0   3.888669    3.699282       0.185973         375.547956  0.116702
# 5   5.0   3.890587    3.606377       0.280527         362.636918  0.112690
# 6   6.0   3.897055    3.578773       0.313605         376.240823  0.116918
# 7   7.0   3.892870    3.510276       0.378982         363.615908  0.112994
# 8   8.0   4.013783    3.613350       0.397118         376.448946  0.116982
# 9   9.0   3.896593    3.592025       0.301050         363.903126  0.113084
# 10  10.0  3.889444    3.570854       0.313909         375.613183  0.116723
# ...

# %% [markdown]
# # 2 Nodes

# %% [markdown]
# ### 28 cores:

# %%
load_arrays(N=2, n=28, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   9.707660    8.928137       0.771350         435.935812  0.135468
# 1   1.0   9.694577    8.876556       0.813929         428.234235  0.133075
# 2   2.0   9.746742    8.930476       0.812310         436.005634  0.135490
# 3   3.0   9.700138    8.892477       0.802263         430.633904  0.133820
# 4   4.0   9.694853    8.902584       0.787962         436.055539  0.135505
# 5   5.0   9.698370    8.871589       0.822859         428.642704  0.133202
# 6   6.0   9.698285    8.938891       0.755281         435.724751  0.135402
# 7   7.0   9.697406    8.907968       0.784214         428.779007  0.133244
# 8   8.0   9.698518    8.933022       0.760105         435.545407  0.135347
# 9   9.0   9.701124    8.891980       0.804887         428.140499  0.133046
# 10  10.0  9.702182    8.939389       0.758749         436.617401  0.135680
# ...

# %% [markdown]
# ### 42 cores:

# %%
load_arrays(N=2, n=42, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   3.817723    2.727563       1.084703         305.890104  0.142540
# 1   1.0   3.816269    2.710788       1.099708         299.369649  0.139501
# 2   2.0   3.813634    2.762095       1.045772         304.244692  0.141773
# 3   3.0   3.816306    2.731489       1.078924         300.448233  0.140004
# 4   4.0   3.808387    2.786666       1.016681         305.044126  0.142145
# 5   5.0   3.814853    2.669755       1.139218         298.372604  0.139037
# 6   6.0   3.809358    2.778994       1.024640         305.419665  0.142320
# 7   7.0   3.812978    2.725509       1.082148         298.575137  0.139131
# 8   8.0   3.809490    2.745902       1.058671         304.341592  0.141818
# 9   9.0   3.815660    2.670168       1.139107         299.759590  0.139683
# 10  10.0  3.816182    2.782523       1.028797         304.472564  0.141945
# ...

# %% [markdown]
# ### 56 cores:

# %%
load_arrays(N=2, n=56, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   3.626679    3.082029       0.541201         259.819604  0.161479
# 1   1.0   3.572789    2.604368       0.962868         254.265044  0.158027
# 2   2.0   3.569870    3.081460       0.484471         259.602669  0.161344
# 3   3.0   3.572803    2.990848       0.578156         252.351373  0.156837
# 4   4.0   3.608733    3.078665       0.526653         259.352551  0.161189
# 5   5.0   3.572802    2.950020       0.618919         253.264833  0.157405
# 6   6.0   3.569617    2.948290       0.617497         259.731728  0.161424
# 7   7.0   3.565204    3.040903       0.519938         252.189416  0.156737
# 8   8.0   3.566151    3.046789       0.515401         259.935731  0.161551
# 9   9.0   3.567994    3.046259       0.517950         253.987415  0.157854
# 10  10.0  3.570003    3.057683       0.508442         259.945388  0.161557
# ...

# %% [markdown]
# # 4 Nodes

# %% [markdown]
# ### 56 cores:

# %%
load_arrays(N=4, n=56, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   7.565173    5.630313       1.927079         352.828382  0.219284
# 1   1.0   7.555001    5.597075       1.949534         353.546361  0.219730
# 2   2.0   7.559291    5.626006       1.925144         352.841353  0.219292
# 3   3.0   7.565405    5.595969       1.961849         353.210613  0.219522
# 4   4.0   7.559257    5.710005       1.841054         354.358295  0.220235
# 5   5.0   7.563038    5.500610       2.054217         354.772993  0.220493
# 6   6.0   7.557431    5.741638       1.807857         352.965041  0.219369
# 7   7.0   7.563513    5.584624       1.971022         353.455475  0.219674
# 8   8.0   7.563762    5.735562       1.820012         353.849559  0.219919
# 9   9.0   7.560898    5.581913       1.971038         351.729109  0.218601
# 10  10.0  7.562915    5.730656       1.824779         355.004573  0.220637
# ...

# %% [markdown]
# ### 74 cores:

# %%
load_arrays(N=4, n=74, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   10.877917   9.741752       1.131401         280.459152  0.230262
# 1   1.0   10.881285   9.705924       1.170686         280.523271  0.230315
# 2   2.0   10.878851   9.742512       1.128703         279.694798  0.229634
# 3   3.0   10.882747   8.829320       2.048674         277.699982  0.227997
# 4   4.0   10.881114   9.775302       1.102481         278.652448  0.228779
# 5   5.0   10.848480   9.717110       1.127728         280.423078  0.230232
# 6   6.0   10.881743   9.746548       1.131950         279.868768  0.229777
# 7   7.0   10.828073   9.457707       1.365219         280.804954  0.230546
# 8   8.0   10.838582   9.752360       1.082680         279.950367  0.229844
# 9   9.0   10.873826   9.506562       1.361854         278.895699  0.228978
# 10  10.0  10.873565   9.746775       1.123381         277.443890  0.227786
# ...

# %% [markdown]
# ### 104 cores:

# %%
load_arrays(N=4, n=56, cols=columns)
# Out:
#     rank  init total  init topology  init trajectory        loop  loop/frame  \
# 0   0.0   7.565173    5.630313       1.927079         352.828382  0.219284
# 1   1.0   7.555001    5.597075       1.949534         353.546361  0.219730
# 2   2.0   7.559291    5.626006       1.925144         352.841353  0.219292
# 3   3.0   7.565405    5.595969       1.961849         353.210613  0.219522
# 4   4.0   7.559257    5.710005       1.841054         354.358295  0.220235
# 5   5.0   7.563038    5.500610       2.054217         354.772993  0.220493
# 6   6.0   7.557431    5.741638       1.807857         352.965041  0.219369
# 7   7.0   7.563513    5.584624       1.971022         353.455475  0.219674
# 8   8.0   7.563762    5.735562       1.820012         353.849559  0.219919
# 9   9.0   7.560898    5.581913       1.971038         351.729109  0.218601
# 10  10.0  7.562915    5.730656       1.824779         355.004573  0.220637
# ...

# %% [markdown]
# # 6 Nodes

# %% [markdown]
# ### 140 cores:

# %%
load_arrays(N=6, n=140, cols=columns)
# Out:
#       rank  init total  init topology  init trajectory        loop  \
# 0    0.0    7.975242    6.908463       1.062249         217.798839
# 1    1.0    7.984622    6.906898       1.073264         227.767951
# 2    2.0    8.888406    6.135317       2.745058         214.705214
# 3    3.0    8.220063    6.912964       1.298990         227.857142
# 4    4.0    7.979418    6.787041       1.187853         220.252205
# 5    5.0    8.698579    6.916807       1.772648         227.654388
# 6    6.0    7.960181    6.828393       1.127206         219.818233
# 7    7.0    7.984481    6.310076       1.669949         228.286965
# 8    8.0    7.954942    6.910240       1.040245         220.135648
# 9    9.0    8.210058    6.898083       1.302768         228.115851
# 10   10.0   7.941319    6.937254       0.999997         217.192075
# 11   11.0   9.481977    6.755881       2.717151         226.610113
# 12   12.0   7.981876    6.293673       1.683374         216.589590
# ...

# %% [markdown]
# ### 154 cores:

# %%
load_arrays(N=6, n=154, cols=columns)
# Out:
#       rank  init total  init topology  init trajectory        loop  \
# 0    0.0    22.257264   21.226034      1.026132         219.691662
# 1    1.0    22.397359   21.305937      1.084211         239.157428
# 2    2.0    22.254008   21.124461      1.124686         216.505553
# 3    3.0    22.527996   21.231503      1.289466         239.827615
# 4    4.0    22.244321   20.711770      1.527014         219.942235
# 5    5.0    22.271129   21.232354      1.033263         240.152136
# 6    6.0    22.255359   21.125846      1.124850         223.628500
# 7    7.0    22.326164   21.124305      1.196170         240.282489
# 8    8.0    22.256761   21.119922      1.131752         224.028369
# 9    9.0    22.444118   21.233583      1.202797         239.809791
# 10   10.0   22.391122   20.713620      1.673123         219.465081
# 11   11.0   22.464699   21.231308      1.226505         239.143214
# 12   12.0   22.363893   21.173914      1.185912         219.246840
# ...

# %% [markdown]
# ### 168 cores:

# %%
load_arrays(N=6, n=168, cols=columns)
# Out:
#       rank  init total  init topology  init trajectory        loop  \
# 0    0.0    9.362044    7.916802       1.441957         214.864766
# 1    1.0    9.354722    7.276578       2.072473         232.780252
# 2    2.0    9.365302    8.040759       1.317615         213.436655
# 3    3.0    9.608147    8.065668       1.535880         232.510516
# 4    4.0    9.376230    7.962276       1.410203         214.846219
# 5    5.0    10.018257   7.961158       2.048764         231.538509
# 6    6.0    9.361073    7.975962       1.378098         213.944517
# 7    7.0    9.565677    8.044257       1.514781         233.419501
# 8    8.0    9.376220    7.987944       1.384908         216.504476
# 9    9.0    9.933115    8.058881       1.868104         233.460722
# 10   10.0   9.349210    7.975436       1.370242         218.287100
# 11   11.0   9.884408    8.058815       1.818999         233.302271
# 12   12.0   9.611389    5.785241       3.816582         215.664834
# ...

# %% [markdown]
# # 8 Nodes

# %% [markdown]
# ### 196 cores:

# %%
load_arrays(N=8, n=196, cols=columns)
# Out:
#       rank  init total  init topology  init trajectory        loop  \
# 0    0.0    11.440167   5.426317       6.007238         176.941918
# 1    1.0    11.550024   5.733361       5.808854         188.369109
# 2    2.0    11.517857   5.693504       5.819278         175.631733
# 3    3.0    11.433596   5.676428       5.750148         187.663096
# 4    4.0    11.480212   5.608916       5.862261         175.569710
# 5    5.0    11.494392   5.490471       5.996327         187.621024
# 6    6.0    11.533409   5.699954       5.828430         175.278506
# 7    7.0    11.521807   5.711997       5.802352         188.466115
# 8    8.0    11.413771   5.482051       5.926578         176.446093
# 9    9.0    11.526308   5.724040       5.794436         187.334018
# 10   10.0   11.493549   5.674200       5.813298         176.834318
# 11   11.0   11.534673   5.653331       5.873130         188.094022
# 12   12.0   11.578338   5.608051       5.964886         175.193401
# ...

# %% [markdown]
# ### 210 cores:

# %%
load_arrays(N=8, n=210, cols=columns)
# Out:
#       rank  init total  init topology  init trajectory        loop  \
# 0    0.0    8.131723    6.867553       1.257855         180.366534
# 1    1.0    8.172767    6.665015       1.501231         191.806796
# 2    2.0    8.144284    6.798749       1.336167         179.114948
# 3    3.0    8.161537    6.910578       1.244320         191.424504
# 4    4.0    8.108448    6.682274       1.419073         178.918744
# 5    5.0    8.155859    6.911906       1.237244         190.668060
# 6    6.0    8.162258    6.697665       1.454939         179.472669
# 7    7.0    8.155515    6.818908       1.330058         190.791381
# 8    8.0    8.108236    6.860756       1.241939         179.544423
# 9    9.0    8.174482    6.810618       1.356981         191.443064
# 10   10.0   8.119307    6.545227       1.566613         179.481525
# 11   11.0   8.164739    6.687931       1.470310         190.999269
# 12   12.0   8.183039    6.807766       1.369844         179.416458
# ...

# %% [markdown]
# ### 224 cores:

# %%
load_arrays(N=8, n=224, cols=columns)
# Out:
#       rank  init total  init topology  init trajectory        loop  \
# 0    0.0    5.790392    4.933208       0.846108         163.906479
# 1    1.0    5.849506    4.902081       0.942541         175.612208
# 2    2.0    5.806669    4.909521       0.891408         163.721194
# 3    3.0    5.795932    4.912045       0.877963         176.124166
# 4    4.0    5.812040    4.950534       0.856447         162.693624
# 5    5.0    5.839823    4.856383       0.977581         175.654215
# 6    6.0    5.767267    4.896206       0.864787         162.687222
# 7    7.0    5.803293    4.892292       0.905085         176.316981
# 8    8.0    5.765887    4.921851       0.837780         164.954909
# 9    9.0    5.776236    4.790552       0.978919         175.651555
# 10   10.0   5.777550    4.896637       0.874639         164.327746
# 11   11.0   5.799768    4.778059       1.016181         176.215263
# 12   12.0   5.816915    4.889283       0.922077         165.564480
# ...
