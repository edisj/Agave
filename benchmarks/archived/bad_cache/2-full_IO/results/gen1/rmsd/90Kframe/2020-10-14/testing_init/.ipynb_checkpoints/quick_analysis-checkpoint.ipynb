# %%
import numpy as np
import pandas as pd

# %%
a28 = np.load('2node/28process_times.npy')
a42 = np.load('2node/42process_times.npy')
a56 = np.load('2node/56process_times.npy')

# %%
columns = ['rank', 'init total', 'init topology', 'init trajectory', 'loop', 'loop/frame', 'io',
          'io/frame', 'rmsd compute', 'rmsd compute/frame', 'communication', 'total bench']

# %%
dframe28 = pd.DataFrame(list(a28), columns=columns).set_index('rank')
dframe28
# Out:
#       init total  init topology  init trajectory        loop  loop/frame  \
# rank
# 0.0     3.666303       2.846197         0.814163  421.602763    0.131014
# 1.0     3.664574       2.650896         1.007664  416.116776    0.129309
# 2.0     3.660103       2.671650         0.982149  422.672361    0.131346
# 3.0     3.656427       2.929273         0.720624  416.238092    0.129347
# 4.0     3.659420       2.883782         0.771370  422.919895    0.131423
# 5.0     3.660708       2.936044         0.720319  415.582761    0.129143
# 6.0     3.817013       2.854529         0.957717  422.760495    0.131374
# 7.0     3.662642       2.945784         0.712846  416.654385    0.129476
# 8.0     3.657228       2.960799         0.692163  422.472967    0.131284
# 9.0     3.650138       2.937512         0.706775  415.688098    0.129176
# 10.0    3.664162       2.954684         0.705362  422.733092    0.131365
# 11.0    3.665821       2.930521         0.729036  417.389324    0.129705
# ...

# %%
dframe42 = pd.DataFrame(list(a42), columns=columns).set_index('rank')
dframe42
# Out:
#       init total  init topology  init trajectory        loop  loop/frame  \
# rank
# 0.0     4.214583       3.533611         0.676380  302.119235    0.140782
# 1.0     4.191406       3.519619         0.667083  292.046106    0.136089
# 2.0     4.199853       3.541826         0.653376  302.356218    0.140893
# 3.0     4.189793       3.516403         0.668789  295.957172    0.137911
# 4.0     4.190354       3.527335         0.658272  302.196259    0.140818
# 5.0     4.187453       3.513037         0.669278  294.781438    0.137363
# 6.0     4.197428       3.529098         0.663572  302.351722    0.140891
# 7.0     4.187179       3.397488         0.785156  295.000614    0.137465
# 8.0     4.187871       3.420082         0.762246  301.736902    0.140604
# 9.0     4.188697       3.492670         0.691310  295.441698    0.137671
# 10.0    4.198222       3.567798         0.625666  302.378600    0.140969
# 11.0    4.190057       3.534756         0.650668  296.131748    0.138057
# ...

# %%
dframe56 = pd.DataFrame(list(a56), columns=columns).set_index('rank')
dframe56
# Out:
#       init total  init topology  init trajectory        loop  loop/frame  \
# rank
# 0.0     4.202771       3.380653         0.817297  241.480805    0.150081
# 1.0     4.200243       3.476190         0.719111  233.088858    0.144866
# 2.0     4.188089       3.622227         0.562478  240.807472    0.149663
# 3.0     4.196024       3.476479         0.714791  235.594234    0.146423
# 4.0     4.199839       3.445981         0.750416  241.153405    0.149878
# 5.0     4.192451       3.313214         0.874530  234.024964    0.145447
# 6.0     4.195840       3.383717         0.807279  240.598539    0.149533
# 7.0     4.191748       3.451767         0.735296  234.992061    0.146049
# 8.0     4.198464       3.465647         0.729372  241.408259    0.150036
# 9.0     4.191047       3.464364         0.723399  234.807523    0.145934
# 10.0    4.204406       3.533514         0.667379  240.917795    0.149731
# 11.0    4.191701       3.469580         0.717475  233.169481    0.144916
# ...
