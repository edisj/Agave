# %%
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import TPR_xvf, H5MD_xvf
from MDAnalysis.analysis.rms import rmsd

# %%
u = mda.Universe(TPR_xvf, H5MD_xvf)

# %%
ca = u.select_atoms('resid 1-5 and name CA')
ref = ca.positions.copy()

# %%
from MDAnalysis.analysis.rms import rmsd

ca = u.select_atoms('resid 1-5 and name CA')
ref = ca.positions.copy()

for ts in u.trajectory[:3]:
    rms = rmsd(ca.positions, ref, superposition=True)
    print (f"Frame: {ts.frame}, RMSD: {rms} A")
# Out:
# Frame: 0, RMSD: 1.9947529471732987e-07 A
# Frame: 1, RMSD: 0.1434909715111529 A
# Frame: 2, RMSD: 0.32936300542745217 A

# %%
import MDAnalysis as mda
u = mda.Universe("topology.psf", "trajectory.h5md")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_code(self, code_obj, result, async_)
#    3325                 else:
# -> 3326                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3327             finally:
#
# <ipython-input-21-6df5ca712a59> in <module>
#       1 import MDAnalysis as mda
# ----> 2 u = mda.Universe("topology.psf", "trajectory.h5md")
#
# c:\users\16235\reu2020\mdanalysis\package\MDAnalysis\core\universe.py in __init__(self, *args, **kwargs)
#     373                                                 topology_format=topology_format,
# --> 374                                                 **kwargs)
#     375
#
# c:\users\16235\reu2020\mdanalysis\package\MDAnalysis\core\universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
# ...

# %%
import MDAnalysis as mda
u = mda.Universe("topology.psf", "trajectory.h5md")
